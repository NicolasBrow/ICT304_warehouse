# %%
#THIS IS NOT MY CODE
#This code was developed by the AI find and adapted to be used to generate the database for our project https://www.phind.com/search?home=true
#Data generated by this code will be changed in part 2 to have more seasonal data



import random
from datetime import datetime, timedelta
import csv

# Inventory data
inventory = [
    {"itemID": 111111, "itemName": "Dog Coat (S)", "itemDesc": "A small sized dog coat. Various color options.", "itemPrice": 16.99},
    {"itemID": 111112, "itemName": "Cat Scratching Post", "itemDesc": "Durable scratching post for cats.", "itemPrice": 24.99},
    {"itemID": 111113, "itemName": "Rabbit Hutch", "itemDesc": "Spacious hutch for rabbits with multiple compartments.", "itemPrice": 99.99},
    {"itemID": 111114, "itemName": "Dog Leash (M)", "itemDesc": "Medium-sized dog leash with reflective strips.", "itemPrice": 12.99},
    {"itemID": 111115, "itemName": "Cat Toy Set", "itemDesc": "Set of assorted toys to entertain your cat.", "itemPrice": 19.99},
    {"itemID": 111116, "itemName": "Dog Bed (L)", "itemDesc": "Large orthopedic dog bed for maximum comfort.", "itemPrice": 49.99},
    {"itemID": 111117, "itemName": "Bird Cage", "itemDesc": "Stylish cage for small birds.", "itemPrice": 29.99},
    {"itemID": 111118, "itemName": "Fish Tank (20 gallons)", "itemDesc": "Aquarium suitable for small fish.", "itemPrice": 79.99},
    {"itemID": 111119, "itemName": "Hamster Wheel", "itemDesc": "Silent-running wheel for hamsters.", "itemPrice": 9.99},
    {"itemID": 111120, "itemName": "Dog Chew Toy", "itemDesc": "Durable chew toy for dogs. Helps with dental health.", "itemPrice": 8.99},
    {"itemID": 111121, "itemName": "Cat Litter Box", "itemDesc": "Spacious litter box with odor control.", "itemPrice": 34.99},
    {"itemID": 111122, "itemName": "Rabbit Hay Feeder", "itemDesc": "Convenient feeder for rabbits to access hay.", "itemPrice": 14.99},
    {"itemID": 111123, "itemName": "Dog Food Bowl (S)", "itemDesc": "Small-sized stainless steel bowl for dogs.", "itemPrice": 6.99},
    {"itemID": 111124, "itemName": "Cat Collar", "itemDesc": "Adjustable collar with bell for safety.", "itemPrice": 5.99},
    {"itemID": 111125, "itemName": "Bird Perch", "itemDesc": "Natural wood perch for birds to rest and play.", "itemPrice": 7.99},
    {"itemID": 111126, "itemName": "Guinea Pig Cage", "itemDesc": "Cozy cage for guinea pigs with multiple levels.", "itemPrice": 39.99},
    {"itemID": 111127, "itemName": "Dog Grooming Brush", "itemDesc": "Soft-bristled brush for grooming dogs.", "itemPrice": 11.99},
    {"itemID": 111128, "itemName": "Catnip", "itemDesc": "Premium catnip to entice your cat.", "itemPrice": 3.99},
    {"itemID": 111129, "itemName": "Turtle Tank", "itemDesc": "Tank setup for turtles with basking area.", "itemPrice": 89.99},
    {"itemID": 111130, "itemName": "Ferret Tunnel", "itemDesc": "Tunnel system for ferrets to explore and play.", "itemPrice": 17.99},
    {"itemID": 111131, "itemName": "Dog Treats", "itemDesc": "Assorted flavors of treats for dogs.", "itemPrice": 9.99},
    {"itemID": 111132, "itemName": "Cat Tree", "itemDesc": "Multi-level tree for cats to climb and scratch.", "itemPrice": 59.99},
    {"itemID": 111133, "itemName": "Rabbit Water Bottle", "itemDesc": "Drip-resistant water bottle for rabbits.", "itemPrice": 8.99},
    {"itemID": 111134, "itemName": "Dog Poop Bags", "itemDesc": "Biodegradable bags for convenient waste disposal.", "itemPrice": 4.99},
    {"itemID": 111135, "itemName": "Fish Food", "itemDesc": "Nutritious food pellets for fish.", "itemPrice": 12.99},
    {"itemID": 111136, "itemName": "Hamster Cage", "itemDesc": "Compact cage with exercise wheel for hamsters.", "itemPrice": 29.99},
    {"itemID": 111137, "itemName": "Dog Training Clicker", "itemDesc": "Clicker tool for positive reinforcement training.", "itemPrice": 3.99},
    {"itemID": 111138, "itemName": "Cat Bed (M)", "itemDesc": "Medium-sized cozy bed for cats.", "itemPrice": 19.99},
    {"itemID": 111139, "itemName": "Bird Swing", "itemDesc": "Swing perch for birds to exercise and relax.", "itemPrice": 6.99},
    {"itemID": 111140, "itemName": "Rabbit Chew Toy", "itemDesc": "Chewable toy for rabbits to keep their teeth healthy.", "itemPrice": 5.99},
    {"itemID": 111141, "itemName": "Dog Cooling Mat", "itemDesc": "Cooling mat for dogs to beat the heat.", "itemPrice": 21.99},
    {"itemID": 111142, "itemName": "Cat Tunnel", "itemDesc": "Interactive tunnel for cats to play and hide.", "itemPrice": 14.99},
    {"itemID": 111143, "itemName": "Bird Feeder", "itemDesc": "Hanging feeder for wild birds.", "itemPrice": 10.99},
    {"itemID": 111144, "itemName": "Fish Tank Heater", "itemDesc": "Adjustable heater for maintaining optimal aquarium temperature.", "itemPrice": 19.99},
    {"itemID": 111145, "itemName": "Hamster Bedding", "itemDesc": "Soft bedding material for hamsters' comfort.", "itemPrice": 7.99},
    {"itemID": 111146, "itemName": "Dog Raincoat (M)", "itemDesc": "Medium-sized raincoat for dogs.", "itemPrice": 18.99},
    {"itemID": 111147, "itemName": "Catnip Toys Set", "itemDesc": "Set of toys infused with catnip for endless fun.", "itemPrice": 12.99},
    {"itemID": 111148, "itemName": "Rabbit Nail Clippers", "itemDesc": "Clippers designed for safely trimming rabbit nails.", "itemPrice": 9.99},
    {"itemID": 111149, "itemName": "Dog Dental Chew", "itemDesc": "Dental chew toy for dogs to promote oral health.", "itemPrice": 10.99},
    {"itemID": 111150, "itemName": "Bird Cage Cover", "itemDesc": "Cover to provide privacy and darkness for birds.", "itemPrice": 15.99},
    {"itemID": 111151, "itemName": "Fish Tank Decorations", "itemDesc": "Assorted decorations to beautify aquariums.", "itemPrice": 24.99},
    {"itemID": 111152, "itemName": "Guinea Pig Hay Rack", "itemDesc": "Wall-mounted rack for easy access to hay for guinea pigs.", "itemPrice": 11.99},
    {"itemID": 111153, "itemName": "Dog Frisbee", "itemDesc": "Durable frisbee toy for interactive play with dogs.", "itemPrice": 7.99},
    {"itemID": 111154, "itemName": "Cat Water Fountain", "itemDesc": "Fountain to provide running water for cats.", "itemPrice": 29.99},
    {"itemID": 111155, "itemName": "Bird Bath", "itemDesc": "Plastic bath for birds to bathe and stay clean.", "itemPrice": 9.99},
    {"itemID": 111156, "itemName": "Rabbit Grooming Kit", "itemDesc": "Grooming tools for rabbits. Including brush and comb.", "itemPrice": 16.99},
    {"itemID": 111157, "itemName": "Dog GPS Tracker", "itemDesc": "GPS tracker to monitor your dog's location.", "itemPrice": 49.99},
    {"itemID": 111158, "itemName": "Cat Carrier", "itemDesc": "Sturdy carrier for transporting cats safely.", "itemPrice": 39.99},
    {"itemID": 111159, "itemName": "Bird Aviary", "itemDesc": "Spacious aviary for housing multiple birds.", "itemPrice": 129.99},
    {"itemID": 111160, "itemName": "Fish Tank Filter", "itemDesc": "Efficient filter system to maintain aquarium water quality.", "itemPrice": 39.99},
]

# Generate invoices
invoices = []
invoice_id = 1
customer_id = 1
start_date = datetime(2022, 1, 1)
end_date = datetime(2024, 3, 31)
current_date = start_date

while current_date <= end_date:
    # Generate random number of sales for the day
    num_sales = random.randint(1, len(inventory))
    
    for _ in range(num_sales):
        item = random.choice(inventory)
        item_id = item["itemID"]
        item_name = item["itemName"]
        item_desc = item["itemDesc"]
        item_price = item["itemPrice"]
        item_qty = random.randint(25, 100)  # Random quantity between 1 and 5
        total_cost = item_qty * item_price
        
        invoices.append({
            "invoiceID": invoice_id,
            "customerID": customer_id,
            "itemID": item_id,
            "itemPrice": item_price,
            "itemQTY": item_qty,
            "totalCost": total_cost,
            "dateInvoiced": current_date.strftime("%Y-%m-%d")
        })
        
        invoice_id += 1
        customer_id += 1
    
    current_date += timedelta(days=1)

# Write invoices to CSV
csv_filename = "invoices_tester.csv"
with open(csv_filename, mode='w', newline='') as csv_file:
    fieldnames = ["invoiceID", "customerID", "itemID", "itemName", "itemDesc", "itemPrice", "itemQTY", "totalCost", "dateInvoiced"]
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for invoice in invoices:
        writer.writerow(invoice)

print(f"Invoices have been written to {csv_filename}")
# Out:
# Invoices have been written to invoices_tester.csv
